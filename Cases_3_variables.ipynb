# %% [markdown]
# #Cases with 3 variables

# %% [markdown]
# This file contains the cases used in the simulations with 3 variables for 7, 11, 14, 18 and 21 criteria. Each exercise counts with the variables *ranking_table*, *available_budget*, *cost_matrix_client* with the following format.

# %% [markdown]
# - *ranking_table*: Python dictionary containing the different clients as keys and an array of positions of each client in each criteria as values.

# %% [markdown]
# - *available_budget*: Python Int representing the maximum budget available to be spent for improvements.

# %% [markdown]
# - *cost_matrix_client*: Python dictionary containing the targeted client as key and a second dictionary as value. This second dictionary is composed of tuples representing (criteria, position t - 1) as keys and the improvement costs as values. The "forbidden movements", like worsening one position, have been disabled by configuring a budget greater than the available one e.g. *available_budget + 1*.

# %% [markdown]
# ##7 criteria

# %%
ranking_table = {1: [3, 2, 2, 3, 3, 1, 3],
                 2: [1, 1, 3, 2, 2, 3, 1],
                 3: [2, 3, 1, 1, 1, 2, 2]}

available_budget = 17

cost_matrix_client =  {1: {(1, 3): 1, (1, 2): 5,
                           (2, 3): available_budget+1, (2, 2): 3,
                           (3, 3): available_budget+1, (3, 2): 8,
                           (4, 3): 3, (4, 2): 2,
                           (5, 3): 8, (5, 2): 5,
                           (6, 3): available_budget+1, (6, 2): available_budget+1,
                           (7, 3): 4, (7, 2): 8}}

# %% [markdown]
# ##11 criteria

# %%
ranking_table = {1: [3, 3, 2, 1, 3, 3, 3, 3, 1, 3, 1],
                 2: [1, 1, 3, 3, 2, 1, 2, 1, 3, 1, 2],
                 3: [2, 2, 1, 2, 1, 2, 1, 2, 2, 2, 3]}

available_budget = 15

cost_matrix_client =  {1: {(1, 3): 3, (1, 2): 6,
                           (2, 3): 6, (2, 2): 5,
                           (3, 3): available_budget+1, (3, 2): 4,
                           (4, 3): available_budget+1, (4, 2): available_budget+1,
                           (5, 3): 8, (5, 2): 7,
                           (6, 3): 3, (6, 2): 8,
                           (7, 3): 5, (7, 2): 4,
                           (8, 3): 7, (8, 2): 2,
                           (9, 3): available_budget+1, (9, 2): available_budget+1,
                           (10, 3): 7, (10, 2): 2,
                           (11, 3): available_budget+1, (11, 2): available_budget+1}}

# %% [markdown]
# ##14 criteria

# %%
ranking_table = {1: [1, 1, 2, 1, 3, 3, 2, 3, 3, 2, 2, 1, 3, 3],
                 2: [2, 3, 1, 2, 1, 2, 1, 1, 1, 1, 1, 2, 1, 2],
                 3: [3, 2, 3, 3, 2, 1, 3, 2, 2, 3, 3, 3, 2, 1]}

available_budget = 21

cost_matrix_client =  {3: {(1, 3): 1, (1, 2): 4,
                           (2, 3): available_budget+1, (2, 2): 9,
                           (3, 3): 3, (3, 2): 4,
                           (4, 3): 7, (4, 2): 8,
                           (5, 3): available_budget+1, (5, 2): 7,
                           (6, 3): available_budget+1, (6, 2): available_budget+1,
                           (7, 3): 1, (7, 2): 7,
                           (8, 3): available_budget+1, (8, 2): 1,
                           (9, 3): available_budget+1, (9, 2): 5,
                           (10, 3): 4, (10, 2): 4,
                           (11, 3): 3, (11, 2): 5,
                           (12, 3): 5, (12, 2): 7,
                           (13, 3): available_budget+1, (13, 2): 6,
                           (14, 3): available_budget+1, (14, 2): available_budget+1}}

# %% [markdown]
# ##18 criteria

# %%
ranking_table = {1: [2, 2, 2, 3, 2, 1, 2, 3, 3, 1, 1, 1, 3, 2, 3, 3, 3, 2],
                 2: [3, 1, 3, 2, 1, 2, 1, 2, 2, 3, 2, 2, 1, 1, 2, 2, 1, 3],
                 3: [1, 3, 1, 1, 3, 3, 3, 1, 1, 2, 3, 3, 2, 3, 1, 1, 2, 1]}

available_budget = 13

cost_matrix_client =  {1: {(1, 3): available_budget+1, (1, 2): 7,
                           (2, 3): available_budget+1, (2, 2): 4,
                           (3, 3): available_budget+1, (3, 2): 7,
                           (4, 3): 7, (4, 2): 5,
                           (5, 3): available_budget+1, (5, 2): 3,
                           (6, 3): available_budget+1, (6, 2): available_budget+1,
                           (7, 3): available_budget+1, (7, 2): 7,
                           (8, 3): 9, (8, 2): 6,
                           (9, 3): 8, (9, 2): 8,
                           (10, 3): available_budget+1, (10, 2): available_budget+1,
                           (11, 3): available_budget+1, (11, 2): available_budget+1,
                           (12, 3): available_budget+1, (12, 2): available_budget+1,
                           (13, 3): 9, (13, 2): 7,
                           (14, 3): available_budget+1, (14, 2): 1,
                           (15, 3): 3, (15, 2): 7,
                           (16, 3): 5, (16, 2): 3,
                           (17, 3): 6, (17, 2): 8,
                           (18, 3): available_budget+1, (18, 2): 2}}

# %% [markdown]
# ##21 criteria

# %%
ranking_table = {1: [1, 2, 2, 2, 1, 1, 3, 1, 3, 3, 2, 1, 1, 2, 2, 1, 2, 2, 2, 2, 2],
                 2: [2, 1, 1, 1, 2, 2, 2, 2, 2, 2, 1, 3, 3, 1, 3, 2, 3, 3, 3, 1, 3],
                 3: [3, 3, 3, 3, 3, 3, 1, 3, 1, 1, 3, 2, 2, 3, 1, 3, 1, 1, 1, 3, 1]}

available_budget = 18

cost_matrix_client =  {3: {(1, 3): 6, (1, 2): 9,
                           (2, 3): 9, (2, 2): 2,
                           (3, 3): 1, (3, 2): 2,
                           (4, 3): 6, (4, 2): 9,
                           (5, 3): 3, (5, 2): 8,
                           (6, 3): 9, (6, 2): 9,
                           (7, 3): available_budget+1, (7, 2): available_budget+1,
                           (8, 3): 2, (8, 2): 4,
                           (9, 3): available_budget+1, (9, 2): available_budget+1,
                           (10, 3): available_budget+1, (10, 2): available_budget+1,
                           (11, 3): 8, (11, 2): 5,
                           (12, 3): available_budget+1, (12, 2): 2,
                           (13, 3): available_budget+1, (13, 2): 9,
                           (14, 3): 7, (14, 2): 5,
                           (15, 3): available_budget+1, (15, 2): available_budget+1,
                           (16, 3): 7, (16, 2): 4,
                           (17, 3): available_budget+1, (17, 2): available_budget+1,
                           (18, 3): available_budget+1, (18, 2): available_budget+1,
                           (19, 3): available_budget+1, (19, 2): available_budget+1,
                           (20, 3): 4, (20, 2): 5,
                           (21, 3): available_budget+1, (21, 2): available_budget+1}}
