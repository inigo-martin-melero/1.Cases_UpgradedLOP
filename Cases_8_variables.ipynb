# %% [markdown]
# #Cases with 8 variables

# %% [markdown]
# This file contains the cases used in the simulations with 8 variables for 7, 11, 14, 18 and 21 criteria. Each exercise counts with the variables *ranking_table*, *available_budget*, *cost_matrix_client* with the following format.

# %% [markdown]
# - *ranking_table*: Python dictionary containing the different clients as keys and an array of positions of each client in each criteria as values.

# %% [markdown]
# - *available_budget*: Python Int representing the maximum budget available to be spent for improvements.

# %% [markdown]
# - *cost_matrix_client*: Python dictionary containing the targeted client as key and a second dictionary as value. This second dictionary is composed of tuples representing (criteria, position t - 1) as keys and the improvement costs as values. The "forbidden movements", like worsening one position, have been disabled by configuring a budget greater than the available one e.g. *available_budget + 1*.

# %% [markdown]
# ##7 criteria

# %%
ranking_table = {1: [7, 2, 1, 8, 1, 8, 2],
                 2: [2, 7, 7, 6, 5, 1, 6],
                 3: [4, 1, 5, 1, 7, 4, 3],
                 4: [3, 5, 3, 5, 2, 7, 7],
                 5: [1, 3, 6, 3, 6, 5, 1],
                 6: [8, 4, 4, 2, 3, 6, 8],
                 7: [5, 8, 8, 7, 4, 2, 5],
                 8: [6, 6, 2, 4, 8, 3, 4]}

available_budget = 28

cost_matrix_client =   {4: {(1,8):available_budget+1,(1,7):available_budget+1,(1,6):available_budget+1,(1,5):available_budget+1,(1,4):available_budget+1,(1,3):9,(1,2):2,
                            (2,8):available_budget+1,(2,7):available_budget+1,(2,6):available_budget+1,(2,5):8,(2,4):3,(2,3):6,(2,2):7,
                            (3,8):available_budget+1,(3,7):available_budget+1,(3,6):available_budget+1,(3,5):available_budget+1,(3,4):available_budget+1,(3,3):5,(3,2):6,
                            (4,8):available_budget+1,(4,7):available_budget+1,(4,6):available_budget+1,(4,5):3,(4,4):7,(4,3):5,(4,2):8,
                            (5,8):available_budget+1,(5,7):available_budget+1,(5,6):available_budget+1,(5,5):available_budget+1,(5,4):available_budget+1,(5,3):available_budget+1,(5,2):3,
                            (6,8):available_budget+1,(6,7):8,(6,6):6,(6,5):4,(6,4):5,(6,3):9,(6,2):2,
                            (7,8):available_budget+1,(7,7):3,(7,6):7,(7,5):5,(7,4):8,(7,3):2,(7,2):1}}

# %% [markdown]
# ##11 criteria

# %%
ranking_table = {1: [6, 1, 6, 8, 5, 3, 3, 1, 6, 6, 4],
                 2: [2, 5, 1, 7, 4, 7, 4, 6, 4, 3, 7],
                 3: [3, 6, 4, 6, 6, 4, 1, 2, 8, 7, 1],
                 4: [8, 8, 7, 5, 7, 6, 6, 4, 7, 2, 5],
                 5: [4, 7, 3, 3, 8, 1, 5, 3, 3, 1, 3],
                 6: [5, 2, 8, 2, 1, 5, 8, 5, 5, 4, 2],
                 7: [7, 3, 5, 1, 3, 2, 7, 8, 2, 5, 6],
                 8: [1, 4, 2, 4, 2, 8, 2, 7, 1, 8, 8]}

available_budget = 69

cost_matrix_client =  {4: {(1,8):4,(1,7):6,(1,6):7,(1,5):3,(1,4):5,(1,3):9,(1,2):2,
                           (2,8):1,(2,7):5,(2,6):3,(2,5):8,(2,4):3,(2,3):6,(2,2):7,
                           (3,8):available_budget+1,(3,7):2,(3,6):6,(3,5):7,(3,4):8,(3,3):5,(3,2):1,
                           (4,8):available_budget+1,(4,7):available_budget+1,(4,6):available_budget+1,(4,5):3,(4,4):7,(4,3):5,(4,2):8,
                           (5,8):available_budget+1,(5,7):4,(5,6):2,(5,5):6,(5,4):7,(5,3):available_budget+1,(5,2):3,
                           (6,8):available_budget+1,(6,7):available_budget+1,(6,6):3,(6,5):4,(6,4):8,(6,3):3,(6,2):2,
                           (7,8):available_budget+1,(7,7):available_budget+1,(7,6):5,(7,5):2,(7,4):7,(7,3):3,(7,2):1,
                           (8,8):available_budget+1,(8,7):available_budget+1,(8,6):available_budget+1,(8,5):available_budget+1,(8,4):7,(8,3):3,(8,2):1,
                           (9,8):available_budget+1,(9,7):5,(9,6):2,(9,5):8,(9,4):3,(9,3):2,(9,2):7,
                           (10,8):available_budget+1,(10,7):available_budget+1,(10,6):available_budget+1,(10,5):available_budget+1,(10,4):available_budget+1,(10,3):available_budget+1,(10,2):5,
                           (11,8):available_budget+1,(11,7):available_budget+1,(11,6):available_budget+1,(11,5):4,(11,4):7,(11,3):5,(11,2):1}}

# %% [markdown]
# ##14 criteria

# %%
ranking_table = {1: [5, 8, 4, 5, 8, 5, 4, 2, 5, 2, 1, 3, 3, 5],
                 2: [2, 1, 1, 6, 6, 8, 7, 5, 2, 8, 7, 7, 4, 7],
                 3: [7, 3, 5, 7, 1, 3, 6, 8, 3, 1, 6, 2, 1, 1],
                 4: [4, 6, 6, 8, 7, 6, 5, 7, 8, 6, 8, 6, 7, 6],
                 5: [3, 2, 2, 1, 3, 7, 2, 1, 1, 4, 5, 4, 6, 2],
                 6: [8, 4, 8, 2, 4, 2, 3, 6, 7, 7, 4, 1, 5, 8],
                 7: [6, 5, 7, 3, 5, 4, 1, 3, 6, 3, 2, 5, 2, 3],
                 8: [1, 7, 3, 4, 2, 1, 8, 4, 4, 5, 3, 8, 8, 4]}

available_budget = 176

cost_matrix_client =  {4: {(1,8):available_budget+1,(1,7):available_budget+1,(1,6):available_budget+1,(1,5):available_budget+1,(1,4):6,(1,3):3,(1,2):8,
                           (2,8):available_budget+1,(2,7):available_budget+1,(2,6):9,(2,5):5,(2,4):3,(2,3):7,(2,2):2,
                           (3,8):available_budget+1,(3,7):available_budget+1,(3,6):5,(3,5):3,(3,4):1,(3,3):7,(3,2):4,
                           (4,8):3,(4,7):5,(4,6):2,(4,5):6,(4,4):6,(4,3):1,(4,2):4,
                           (5,8):available_budget+1,(5,7):6,(5,6):9,(5,5):2,(5,4):4,(5,3):5,(5,2):7,
                           (6,8):available_budget+1,(6,7):available_budget+1,(6,6):3,(6,5):8,(6,4):7,(6,3):5,(6,2):2,
                           (7,8):available_budget+1,(7,7):available_budget+1,(7,6):available_budget+1,(7,5):4,(7,4):9,(7,3):2,(7,2):7,
                           (8,8):available_budget+1,(8,7):1,(8,6):6,(8,5):4,(8,4):3,(8,3):7,(8,2):2,
                           (9,8):6,(9,7):9,(9,6):4,(9,5):3,(9,4):6,(9,3):2,(9,2):7,
                           (10,8):available_budget+1,(10,7):available_budget+1,(10,6):4,(10,5):5,(10,4):2,(10,3):7,(10,2):3,
                           (11,8):8,(11,7):5,(11,6):3,(11,5):7,(11,4):4,(11,3):2,(11,2):8,
                           (12,8):available_budget+1,(12,7):available_budget+1,(12,6):5,(12,5):7,(12,4):3,(12,3):5,(12,2):4,
                           (13,8):available_budget+1,(13,7):9,(13,6):4,(13,5):6,(13,4):4,(13,3):2,(13,2):7,
                           (14,8):available_budget+1,(14,7):available_budget+1,(14,6):5,(14,5):2,(14,4):5,(14,3):7,(14,2):8}}

# %% [markdown]
# ##18 criteria

# %%
ranking_table = {1: [3, 2, 5, 3, 4, 2, 8, 3, 3, 7, 7, 1, 2, 4, 3, 4, 8, 2],
                 2: [8, 1, 4, 7, 7, 5, 4, 8, 4, 2, 1, 8, 8, 1, 7, 1, 4, 4],
                 3: [7, 4, 6, 2, 6, 1, 5, 6, 2, 6, 3, 2, 3, 2, 2, 5, 1, 5],
                 4: [6, 8, 2, 8, 2, 7, 2, 4, 6, 8, 8, 5, 4, 3, 8, 6, 7, 7],
                 5: [4, 6, 1, 4, 1, 8, 3, 1, 7, 3, 4, 3, 7, 7, 1, 8, 5, 1],
                 6: [2, 3, 7, 5, 8, 6, 6, 7, 5, 4, 2, 7, 5, 6, 5, 3, 6, 6],
                 7: [1, 7, 8, 1, 3, 4, 1, 5, 8, 1, 6, 4, 1, 5, 6, 7, 2, 3],
                 8: [5, 5, 3, 6, 5, 3, 7, 2, 1, 5, 5, 6, 6, 8, 4, 2, 3, 8]}

available_budget = 110

cost_matrix_client =  {4: {(1,8):available_budget+1,(1,7):available_budget+1,(1,6):4,(1,5):6,(1,4):1,(1,3):4,(1,2):2,
                           (2,8):6,(2,7):8,(2,6):2,(2,5):4,(2,4):3,(2,3):1,(2,2):2,
                           (3,8):available_budget+1,(3,7):available_budget+1,(3,6):available_budget+1,(3,5):available_budget+1,(3,4):available_budget+1,(3,3):available_budget+1,(3,2):5,
                           (4,8):8,(4,7):5,(4,6):3,(4,5):7,(4,4):2,(4,3):1,(4,2):6,
                           (5,8):available_budget+1,(5,7):available_budget+1,(5,6):available_budget+1,(5,5):available_budget+1,(5,4):available_budget+1,(5,3):available_budget+1,(5,2):5,
                           (6,8):available_budget+1,(6,7):9,(6,6):5,(6,5):3,(6,4):5,(6,3):1,(6,2):5,
                           (7,8):available_budget+1,(7,7):available_budget+1,(7,6):available_budget+1,(7,5):available_budget+1,(7,4):available_budget+1,(7,3):available_budget+1,(7,2):7,
                           (8,8):available_budget+1,(8,7):available_budget+1,(8,6):available_budget+1,(8,5):available_budget+1,(8,4):8,(8,3):6,(8,2):3,
                           (9,8):available_budget+1,(9,7):available_budget+1,(9,6):5,(9,5):7,(9,4):1,(9,3):3,(9,2):4,
                           (10,8):9,(10,7):4,(10,6):3,(10,5):5,(10,4):6,(10,3):7,(10,2):1,
                           (11,8):5,(11,7):3,(11,6):7,(11,5):5,(11,4):1,(11,3):3,(11,2):7,
                           (12,8):available_budget+1,(12,7):available_budget+1,(12,6):available_budget+1,(12,5):4,(12,4):3,(12,3):7,(12,2):1,
                           (13,8):available_budget+1,(13,7):available_budget+1,(13,6):available_budget+1,(13,5):available_budget+1,(13,4):6,(13,3):2,(13,2):4,
                           (14,8):available_budget+1,(14,7):available_budget+1,(14,6):available_budget+1,(14,5):available_budget+1,(14,4):available_budget+1,(14,3):6,(14,2):2,
                           (15,8):3,(15,7):7,(15,6):2,(15,5):5,(15,4):4,(15,3):1,(15,2):5,
                           (16,8):available_budget+1,(16,7):available_budget+1,(16,6):1,(16,5):9,(16,4):6,(16,3):4,(16,2):3,
                           (17,8):available_budget+1,(17,7):4,(17,6):1,(17,5):3,(17,4):7,(17,3):9,(17,2):2,
                           (18,8):available_budget+1,(18,7):5,(18,6):7,(18,5):9,(18,4):3,(18,3):1,(18,2):4}}

# %% [markdown]
# ##21 criteria

# %%
ranking_table = {1: [1, 6, 5, 5, 3, 4, 3, 8, 7, 4, 3, 4, 2, 6, 5, 7, 6, 5, 8, 7, 4],
                 2: [2, 5, 6, 3, 7, 3, 8, 6, 6, 5, 2, 2, 6, 7, 8, 3, 4, 8, 5, 5, 6],
                 3: [5, 1, 3, 4, 2, 1, 5, 3, 3, 3, 8, 7, 7, 1, 4, 2, 2, 3, 4, 6, 5],
                 4: [3, 2, 8, 2, 8, 6, 6, 5, 1, 2, 6, 5, 3, 8, 2, 6, 7, 6, 1, 2, 8],
                 5: [4, 4, 4, 1, 5, 5, 2, 2, 8, 7, 1, 1, 1, 3, 3, 4, 5, 7, 2, 4, 7],
                 6: [8, 8, 1, 8, 4, 8, 4, 1, 2, 1, 5, 6, 8, 4, 6, 1, 3, 4, 7, 3, 2],
                 7: [7, 3, 7, 6, 1, 2, 1, 4, 5, 6, 7, 3, 5, 2, 7, 8, 8, 2, 6, 1, 3],
                 8: [6, 7, 2, 7, 6, 7, 7, 7, 4, 8, 4, 8, 4, 5, 1, 5, 1, 1, 3, 8, 1]}

available_budget = 24

cost_matrix_client =  {4: {(1,8):available_budget+1,(1,7):available_budget+1,(1,6):available_budget+1,(1,5):available_budget+1,(1,4):available_budget+1,(1,3):4,(1,2):2,
                           (2,8):available_budget+1,(2,7):available_budget+1,(2,6):available_budget+1,(2,5):available_budget+1,(2,4):available_budget+1,(2,3):available_budget+1,(2,2):3,
                           (3,8):1,(3,7):6,(3,6):2,(3,5):4,(3,4):7,(3,3):3,(3,2):2,
                           (4,8):available_budget+1,(4,7):available_budget+1,(4,6):available_budget+1,(4,5):available_budget+1,(4,4):available_budget+1,(4,3):available_budget+1,(4,2):6,
                           (5,8):4,(5,7):8,(5,6):5,(5,5):7,(5,4):1,(5,3):5,(5,2):3,
                           (6,8):available_budget+1,(6,7):available_budget+1,(6,6):4,(6,5):7,(6,4):8,(6,3):2,(6,2):3,
                           (7,8):available_budget+1,(7,7):available_budget+1,(7,6):2,(7,5):5,(7,4):8,(7,3):4,(7,2):1,
                           (8,8):available_budget+1,(8,7):available_budget+1,(8,6):available_budget+1,(8,5):1,(8,4):7,(8,3):3,(8,2):5,
                           (9,8):available_budget+1,(9,7):available_budget+1,(9,6):available_budget+1,(9,5):available_budget+1,(9,4):available_budget+1,(9,3):available_budget+1,(9,2):available_budget+1,
                           (10,8):available_budget+1,(10,7):available_budget+1,(10,6):available_budget+1,(10,5):available_budget+1,(10,4):available_budget+1,(10,3):available_budget+1,(10,2):9,
                           (11,8):available_budget+1,(11,7):available_budget+1,(11,6):4,(11,5):6,(11,4):2,(11,3):5,(11,2):3,
                           (12,8):available_budget+1,(12,7):available_budget+1,(12,6):available_budget+1,(12,5):7,(12,4):6,(12,3):3,(12,2):4,
                           (13,8):available_budget+1,(13,7):available_budget+1,(13,6):available_budget+1,(13,5):available_budget+1,(13,4):available_budget+1,(13,3):6,(13,2):8,
                           (14,8):4,(14,7):1,(14,6):7,(14,5):3,(14,4):2,(14,3):6,(14,2):5,
                           (15,8):available_budget+1,(15,7):available_budget+1,(15,6):available_budget+1,(15,5):available_budget+1,(15,4):available_budget+1,(15,3):available_budget+1,(15,2):5,
                           (16,8):available_budget+1,(16,7):available_budget+1,(16,6):2,(16,5):7,(16,4):3,(16,3):5,(16,2):4,
                           (17,8):available_budget+1,(17,7):8,(17,6):4,(17,5):6,(17,4):2,(17,3):7,(17,2):3,
                           (18,8):available_budget+1,(18,7):available_budget+1,(18,6):5,(18,5):8,(18,4):1,(18,3):3,(18,2):6,
                           (19,8):available_budget+1,(19,7):available_budget+1,(19,6):available_budget+1,(19,5):available_budget+1,(19,4):available_budget+1,(19,3):available_budget+1,(19,2):available_budget+1,
                           (20,8):available_budget+1,(20,7):available_budget+1,(20,6):available_budget+1,(20,5):available_budget+1,(20,4):available_budget+1,(20,3):available_budget+1,(20,2):3,
                           (21,8):5,(21,7):4,(21,6):2,(21,5):7,(21,4):4,(21,3):3,(21,2):6}}
