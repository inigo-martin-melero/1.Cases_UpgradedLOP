# %% [markdown]
# #Cases with 10 variables

# %% [markdown]
# This file contains the cases used in the simulations with 10 variables for 7, 11, 14, 18 and 21 criteria. Each exercise counts with the variables *ranking_table*, *available_budget*, *cost_matrix_client* with the following format.

# %% [markdown]
# - *ranking_table*: Python dictionary containing the different clients as keys and an array of positions of each client in each criteria as values.

# %% [markdown]
# - *available_budget*: Python Int representing the maximum budget available to be spent for improvements.

# %% [markdown]
# - *cost_matrix_client*: Python dictionary containing the targeted client as key and a second dictionary as value. This second dictionary is composed of tuples representing (criteria, position t - 1) as keys and the improvement costs as values. The "forbidden movements", like worsening one position, have been disabled by configuring a budget greater than the available one e.g. *available_budget + 1*.

# %% [markdown]
# ##7 criteria

# %%
ranking_table = {1: [4, 7, 4, 2, 9, 6, 7],
                 2: [3, 3, 2, 9, 4, 8, 4],
                 3: [1, 6, 9, 8, 1, 9, 10],
                 4: [5, 8, 6, 3, 5, 4, 9],
                 5: [8, 1, 3, 6, 2, 2, 1],
                 6: [6, 9, 5, 5, 7, 10, 3],
                 7: [9, 4, 1, 10, 6, 3, 8],
                 8: [7, 2, 8, 7, 8, 7, 2],
                 9: [2, 10, 10, 4, 3, 5, 5],
                 10: [10, 5, 7, 1, 10, 1, 6]}

available_budget = 18

cost_matrix_client =  {4: {(1,10):available_budget+1,(1,9):available_budget+1,(1,8):available_budget+1,(1,7):available_budget+1,(1,6):available_budget+1,(1,5):6,(1,4):4,(1,3):9,(1,2):2,
                           (2,10):available_budget+1,(2,9):available_budget+1,(2,8):7,(2,7):1,(2,6):3,(2,5):8,(2,4):4,(2,3):6,(2,2):9,
                           (3,10):available_budget+1,(3,9):available_budget+1,(3,8):available_budget+1,(3,7):available_budget+1,(3,6):3,(3,5):6,(3,4):7,(3,3):8,(3,2):6,
                           (4,10):available_budget+1,(4,9):available_budget+1,(4,8):available_budget+1,(4,7):available_budget+1,(4,6):available_budget+1,(4,5):available_budget+1,(4,4):available_budget+1,(4,3):6,(4,2):8,
                           (5,10):available_budget+1,(5,9):available_budget+1,(5,8):available_budget+1,(5,7):available_budget+1,(5,6):available_budget+1,(5,5):4,(5,4):8,(5,3):1,(5,2):3,
                           (6,10):available_budget+1,(6,9):available_budget+1,(6,8):available_budget+1,(6,7):available_budget+1,(6,6):available_budget+1,(6,5):available_budget+1,(6,4):5,(6,3):4,(6,2):2,
                           (7,10):available_budget+1,(7,9):5,(7,8):8,(7,7):3,(7,6):4,(7,5):7,(7,4):3,(7,3):6,(7,2):3}}

# %% [markdown]
# ##11 criteria

# %%
ranking_table = {1: [9, 3, 10, 4, 9, 4, 6, 8, 10, 8, 4],
                 2: [8, 6, 1, 6, 4, 6, 5, 10, 3, 1, 7],
                 3: [7, 10, 4, 3, 6, 2, 2, 3, 4, 5, 8],
                 4: [4, 5, 9, 8, 8, 9, 7, 9, 7, 6, 2],
                 5: [3, 9, 3, 10, 7, 7, 8, 5, 1, 10, 1],
                 6: [6, 1, 8, 5, 5, 10, 3, 6, 2, 9, 6],
                 7: [5, 8, 2, 1, 3, 1, 10, 1, 5, 4, 3],
                 8: [1, 7, 7, 9, 1, 5, 1, 4, 6, 2, 10],
                 9: [10, 2, 5, 2, 2, 3, 4, 2, 8, 7, 5],
                 10: [2, 4, 6, 7, 10, 8, 9, 7, 9, 3, 9]}

available_budget = 28

cost_matrix_client =  {4: {(1,10):available_budget+1,(1,9):available_budget+1,(1,8):available_budget+1,(1,7):available_budget+1,(1,6):available_budget+1,(1,5):available_budget+1,(1,4):8,(1,3):3,(1,2):2,
                           (2,10):available_budget+1,(2,9):available_budget+1,(2,8):available_budget+1,(2,7):available_budget+1,(2,6):available_budget+1,(2,5):5,(2,4):7,(2,3):1,(2,2):3,
                           (3,10):available_budget+1,(3,9):8,(3,8):4,(3,7):7,(3,6):1,(3,5):5,(3,4):7,(3,3):3,(3,2):2,
                           (4,10):available_budget+1,(4,9):available_budget+1,(4,8):5,(4,7):2,(4,6):9,(4,5):1,(4,4):4,(4,3):3,(4,2):6,
                           (5,10):available_budget+1,(5,9):available_budget+1,(5,8):4,(5,7):6,(5,6):5,(5,5):7,(5,4):2,(5,3):8,(5,2):3,
                           (6,10):available_budget+1,(6,9):7,(6,8):6,(6,7):1,(6,6):4,(6,5):7,(6,4):9,(6,3):2,(6,2):3,
                           (7,10):available_budget+1,(7,9):available_budget+1,(7,8):available_budget+1,(7,7):6,(7,6):1,(7,5):8,(7,4):2,(7,3):4,(7,2):3,
                           (8,10):available_budget+1,(8,9):5,(8,8):3,(8,7):1,(8,6):7,(8,5):4,(8,4):8,(8,3):3,(8,2):5,
                           (9,10):available_budget+1,(9,9):available_budget+1,(9,8):available_budget+1,(9,7):6,(9,6):3,(9,5):4,(9,4):2,(9,3):5,(9,2):1,
                           (10,10):available_budget+1,(10,9):available_budget+1,(10,8):available_budget+1,(10,7):available_budget+1,(10,6):8,(10,5):3,(10,4):4,(10,3):6,(10,2):9,
                           (11,10):available_budget+1,(11,9):available_budget+1,(11,8):available_budget+1,(11,7):available_budget+1,(11,6):available_budget+1,(11,5):available_budget+1,(11,4):available_budget+1,(11,3):available_budget+1,(11,2):6}}

# %% [markdown]
# ##14 criteria

# %%
ranking_table = {1: [9, 8, 3, 8, 9, 10, 4, 9, 2, 1, 7, 2, 4, 1],
                 2: [8, 2, 10, 5, 4, 4, 1, 2, 1, 2, 2, 10, 8, 3],
                 3: [10, 1, 7, 7, 2, 7, 9, 6, 10, 7, 9, 7, 1, 7],
                 4: [1, 10, 8, 2, 5, 2, 8, 8, 3, 4, 6, 1, 6, 9],
                 5: [7, 9, 6, 6, 10, 6, 10, 10, 6, 10, 4, 6, 3, 10],
                 6: [6, 7, 4, 4, 1, 8, 6, 7, 7, 9, 1, 4, 9, 2],
                 7: [5, 6, 9, 9, 8, 5, 2, 5, 5, 8, 10, 9, 5, 8],
                 8: [3, 4, 2, 1, 7, 1, 3, 1, 8, 3, 3, 5, 10, 6],
                 9: [2, 5, 1, 10, 6, 3, 7, 3, 4, 6, 5, 8, 2, 5],
                 10: [4, 3, 5, 3, 3, 9, 5, 4, 9, 5, 8, 3, 7, 4]}

available_budget = 35

cost_matrix_client =  {4: {(1,10):available_budget+1,(1,9):available_budget+1,(1,8):available_budget+1,(1,7):available_budget+1,(1,6):available_budget+1,(1,5):available_budget+1,(1,4):available_budget+1,(1,3):available_budget+1,(1,2):available_budget+1,
                           (2,10):5,(2,9):8,(2,8):3,(2,7):7,(2,6):2,(2,5):6,(2,4):3,(2,3):7,(2,2):1,
                           (3,10):available_budget+1,(3,9):available_budget+1,(3,8):6,(3,7):5,(3,6):7,(3,5):1,(3,4):4,(3,3):7,(3,2):2,
                           (4,10):available_budget+1,(4,9):available_budget+1,(4,8):available_budget+1,(4,7):available_budget+1,(4,6):available_budget+1,(4,5):available_budget+1,(4,4):available_budget+1,(4,3):available_budget+1,(4,2):8,
                           (5,10):available_budget+1,(5,9):available_budget+1,(5,8):available_budget+1,(5,7):available_budget+1,(5,6):available_budget+1,(5,5):6,(5,4):3,(5,3):8,(5,2):2,
                           (6,10):available_budget+1,(6,9):available_budget+1,(6,8):available_budget+1,(6,7):available_budget+1,(6,6):available_budget+1,(6,5):available_budget+1,(6,4):available_budget+1,(6,3):available_budget+1,(6,2):4,
                           (7,10):available_budget+1,(7,9):available_budget+1,(7,8):5,(7,7):9,(7,6):3,(7,5):4,(7,4):7,(7,3):2,(7,2):6,
                           (8,10):available_budget+1,(8,9):available_budget+1,(8,8):1,(8,7):4,(8,6):6,(8,5):7,(8,4):9,(8,3):4,(8,2):5,
                           (9,10):available_budget+1,(9,9):available_budget+1,(9,8):available_budget+1,(9,7):available_budget+1,(9,6):available_budget+1,(9,5):available_budget+1,(9,4):available_budget+1,(9,3):6,(9,2):3,
                           (10,10):available_budget+1,(10,9):available_budget+1,(10,8):available_budget+1,(10,7):available_budget+1,(10,6):available_budget+1,(10,5):available_budget+1,(10,4):5,(10,3):8,(10,2):4,
                           (11,10):available_budget+1,(11,9):available_budget+1,(11,8):available_budget+1,(11,7):available_budget+1,(11,6):6,(11,5):9,(11,4):3,(11,3):2,(11,2):5,
                           (12,10):available_budget+1,(12,9):available_budget+1,(12,8):available_budget+1,(12,7):available_budget+1,(12,6):available_budget+1,(12,5):available_budget+1,(12,4):available_budget+1,(12,3):available_budget+1,(12,2):available_budget+1,
                           (13,10):available_budget+1,(13,9):available_budget+1,(13,8):available_budget+1,(13,7):available_budget+1,(13,6):6,(13,5):8,(13,4):5,(13,3):3,(13,2):8,
                           (14,10):available_budget+1,(14,9):8,(14,8):5,(14,7):7,(14,6):6,(14,5):4,(14,4):2,(14,3):1,(14,2):5}}

# %% [markdown]
# ##18 criteria

# %%
ranking_table = {1: [4, 9, 5, 5, 3, 5, 6, 8, 6, 8, 9, 6, 2, 3, 1, 3, 5, 6],
                 2: [7, 7, 9, 10, 6, 3, 4, 6, 1, 10, 3, 2, 6, 2, 9, 10, 4, 5],
                 3: [3, 10, 1, 8, 8, 1, 3, 3, 7, 1, 10, 5, 10, 6, 3, 8, 10, 2],
                 4: [10, 5, 7, 4, 5, 10, 9, 5, 5, 7, 7, 7, 5, 10, 7, 9, 7, 8],
                 5: [9, 1, 4, 7, 10, 2, 10, 7, 3, 3, 5, 8, 7, 5, 8, 2, 3, 7],
                 6: [2, 2, 8, 2, 4, 8, 1, 4, 9, 4, 4, 3, 8, 7, 10, 7, 8, 9],
                 7: [1, 6, 2, 9, 9, 7, 2, 1, 4, 5, 8, 10, 4, 1, 6, 5, 6, 3],
                 8: [8, 3, 10, 1, 7, 4, 5, 2, 2, 6, 2, 9, 3, 4, 4, 6, 2, 10],
                 9: [5, 8, 3, 6, 1, 9, 7, 10, 8, 2, 6, 1, 1, 8, 2, 4, 9, 1],
                 10: [6, 4, 6, 3, 2, 6, 8, 9, 10, 9, 1, 4, 9, 9, 5, 1, 1, 4]}

available_budget = 121

cost_matrix_client =  {4: {(1,10):6,(1,9):3,(1,8):4,(1,7):8,(1,6):2,(1,5):5,(1,4):2,(1,3):4,(1,2):2,
                           (2,10):available_budget+1,(2,9):available_budget+1,(2,8):available_budget+1,(2,7):available_budget+1,(2,6):available_budget+1,(2,5):6,(2,4):4,(2,3):5,(2,2):1,
                           (3,10):available_budget+1,(3,9):available_budget+1,(3,8):available_budget+1,(3,7):8,(3,6):6,(3,5):3,(3,4):1,(3,3):7,(3,2):2,
                           (4,10):available_budget+1,(4,9):available_budget+1,(4,8):available_budget+1,(4,7):available_budget+1,(4,6):available_budget+1,(4,5):available_budget+1,(4,4):6,(4,3):2,(4,2):8,
                           (5,10):available_budget+1,(5,9):available_budget+1,(5,8):available_budget+1,(5,7):available_budget+1,(5,6):available_budget+1,(5,5):7,(5,4):1,(5,3):5,(5,2):3,
                           (6,10):3,(6,9):4,(6,8):8,(6,7):6,(6,6):7,(6,5):2,(6,4):9,(6,3):4,(6,2):5,
                           (7,10):available_budget+1,(7,9):6,(7,8):9,(7,7):7,(7,6):3,(7,5):5,(7,4):1,(7,3):4,(7,2):2,
                           (8,10):available_budget+1,(8,9):available_budget+1,(8,8):available_budget+1,(8,7):available_budget+1,(8,6):available_budget+1,(8,5):8,(8,4):3,(8,3):6,(8,2):5,
                           (9,10):available_budget+1,(9,9):available_budget+1,(9,8):available_budget+1,(9,7):available_budget+1,(9,6):available_budget+1,(9,5):1,(9,4):5,(9,3):4,(9,2):9,
                           (10,10):available_budget+1,(10,9):available_budget+1,(10,8):available_budget+1,(10,7):6,(10,6):3,(10,5):8,(10,4):2,(10,3):4,(10,2):5,
                           (11,10):available_budget+1,(11,9):available_budget+1,(11,8):available_budget+1,(11,7):3,(11,6):8,(11,5):4,(11,4):7,(11,3):2,(11,2):6,
                           (12,10):available_budget+1,(12,9):available_budget+1,(12,8):available_budget+1,(12,7):7,(12,6):2,(12,5):4,(12,4):6,(12,3):3,(12,2):1,
                           (13,10):available_budget+1,(13,9):available_budget+1,(13,8):available_budget+1,(13,7):available_budget+1,(13,6):available_budget+1,(13,5):6,(13,4):7,(13,3):4,(13,2):5,
                           (14,10):8,(14,9):5,(14,8):7,(14,7):1,(14,6):4,(14,5):3,(14,4):7,(14,3):1,(14,2):5,
                           (15,10):available_budget+1,(15,9):available_budget+1,(15,8):available_budget+1,(15,7):6,(15,6):8,(15,5):4,(15,4):5,(15,3):1,(15,2):9,
                           (16,10):available_budget+1,(16,9):1,(16,8):4,(16,7):7,(16,6):6,(16,5):8,(16,4):3,(16,3):1,(16,2):4,
                           (17,10):available_budget+1,(17,9):available_budget+1,(17,8):available_budget+1,(17,7):6,(17,6):2,(17,5):8,(17,4):1,(17,3):5,(17,2):3,
                           (18,10):available_budget+1,(18,9):available_budget+1,(18,8):6,(18,7):3,(18,6):9,(18,5):1,(18,4):5,(18,3):8,(18,2):6}}

# %% [markdown]
# ##21 criteria

# %%
ranking_table = {1: [4, 8, 5, 10, 7, 6, 4, 3, 6, 5, 3, 10, 9, 2, 10, 3, 9, 10, 3, 3, 9],
                 2: [1, 2, 10, 1, 5, 4, 10, 5, 2, 10, 10, 3, 6, 1, 7, 4, 2, 9, 9, 8, 5],
                 3: [2, 5, 2, 6, 8, 9, 6, 10, 5, 9, 9, 4, 2, 6, 5, 2, 5, 1, 2, 5, 8],
                 4: [8, 7, 8, 7, 10, 1, 8, 1, 1, 1, 1, 6, 10, 8, 1, 8, 8, 3, 10, 10, 4],
                 5: [7, 10, 7, 8, 9, 5, 5, 8, 10, 8, 2, 7, 8, 4, 6, 7, 7, 8, 1, 1, 6],
                 6: [3, 3, 6, 3, 2, 8, 7, 6, 8, 7, 8, 1, 4, 5, 9, 6, 3, 4, 6, 2, 10],
                 7: [6, 4, 1, 4, 4, 10, 1, 9, 7, 4, 5, 2, 3, 10, 2, 10, 1, 7, 4, 4, 1],
                 8: [9, 1, 9, 9, 3, 3, 2, 4, 3, 6, 4, 5, 1, 7, 4, 9, 4, 5, 5, 7, 2],
                 9: [5, 9, 3, 2, 6, 2, 9, 2, 9, 2, 6, 8, 5, 3, 3, 5, 10, 6, 8, 9, 3],
                 10: [10, 6, 4, 5, 1, 7, 3, 7, 4, 3, 7, 9, 7, 9, 8, 1, 6, 2, 7, 6, 7]}


available_budget = 24

cost_matrix_client =  {4: {(1,10):available_budget+1,(1,9):available_budget+1,(1,8):7,(1,7):5,(1,6):3,(1,5):2,(1,4):6,(1,3):4,(1,2):2,
                           (2,10):available_budget+1,(2,9):available_budget+1,(2,8):available_budget+1,(2,7):3,(2,6):5,(2,5):8,(2,4):2,(2,3):7,(2,2):3,
                           (3,10):available_budget+1,(3,9):available_budget+1,(3,8):1,(3,7):6,(3,6):2,(3,5):4,(3,4):7,(3,3):3,(3,2):2,
                           (4,10):available_budget+1,(4,9):available_budget+1,(4,8):available_budget+1,(4,7):9,(4,6):4,(4,5):6,(4,4):2,(4,3):5,(4,2):6,
                           (5,10):1,(5,9):4,(5,8):4,(5,7):8,(5,6):5,(5,5):7,(5,4):1,(5,3):5,(5,2):3,
                           (6,10):available_budget+1,(6,9):available_budget+1,(6,8):available_budget+1,(6,7):available_budget+1,(6,6):available_budget+1,(6,5):available_budget+1,(6,4):available_budget+1,(6,3):available_budget+1,(6,2):available_budget+1,
                           (7,10):available_budget+1,(7,9):available_budget+1,(7,8):8,(7,7):5,(7,6):2,(7,5):5,(7,4):8,(7,3):4,(7,2):1,
                           (8,10):available_budget+1,(8,9):available_budget+1,(8,8):available_budget+1,(8,7):available_budget+1,(8,6):available_budget+1,(8,5):available_budget+1,(8,4):available_budget+1,(8,3):available_budget+1,(8,2):available_budget+1,
                           (9,10):available_budget+1,(9,9):available_budget+1,(9,8):available_budget+1,(9,7):available_budget+1,(9,6):available_budget+1,(9,5):available_budget+1,(9,4):available_budget+1,(9,3):available_budget+1,(9,2):available_budget+1,
                           (10,10):available_budget+1,(10,9):available_budget+1,(10,8):available_budget+1,(10,7):available_budget+1,(10,6):available_budget+1,(10,5):available_budget+1,(10,4):available_budget+1,(10,3):available_budget+1,(10,2):available_budget+1,
                           (11,10):available_budget+1,(11,9):available_budget+1,(11,8):available_budget+1,(11,7):available_budget+1,(11,6):available_budget+1,(11,5):available_budget+1,(11,4):available_budget+1,(11,3):available_budget+1,(11,2):available_budget+1,
                           (12,10):available_budget+1,(12,9):available_budget+1,(12,8):available_budget+1,(12,7):available_budget+1,(12,6):2,(12,5):9,(12,4):4,(12,3):5,(12,2):1,
                           (13,10):3,(13,9):5,(13,8):7,(13,7):2,(13,6):4,(13,5):1,(13,4):5,(13,3):6,(13,2):8,
                           (14,10):available_budget+1,(14,9):available_budget+1,(14,8):4,(14,7):2,(14,6):3,(14,5):6,(14,4):2,(14,3):8,(14,2):5,
                           (15,10):available_budget+1,(15,9):available_budget+1,(15,8):available_budget+1,(15,7):available_budget+1,(15,6):available_budget+1,(15,5):available_budget+1,(15,4):available_budget+1,(15,3):available_budget+1,(15,2):available_budget+1,
                           (16,10):available_budget+1,(16,9):available_budget+1,(16,8):6,(16,7):2,(16,6):4,(16,5):7,(16,4):3,(16,3):1,(16,2):4,
                           (17,10):available_budget+1,(17,9):available_budget+1,(17,8):4,(17,7):8,(17,6):2,(17,5):6,(17,4):1,(17,3):7,(17,2):3,
                           (18,10):available_budget+1,(18,9):available_budget+1,(18,8):available_budget+1,(18,7):available_budget+1,(18,6):available_budget+1,(18,5):available_budget+1,(18,4):available_budget+1,(18,3):3,(18,2):6,
                           (19,10):7,(19,9):2,(19,8):4,(19,7):5,(19,6):8,(19,5):1,(19,4):3,(19,3):7,(19,2):2,
                           (20,10):5,(20,9):3,(20,8):8,(20,7):1,(20,6):2,(20,5):4,(20,4):9,(20,3):1,(20,2):3,
                           (21,10):available_budget+1,(21,9):available_budget+1,(21,8):available_budget+1,(21,7):available_budget+1,(21,6):available_budget+1,(21,5):available_budget+1,(21,4):6,(21,3):3,(21,2):2}}
