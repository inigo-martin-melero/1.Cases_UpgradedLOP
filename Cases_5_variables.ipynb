# %% [markdown]
# #Cases with 5 variables

# %% [markdown]
# This file contains the cases used in the simulations with 5 variables for 7, 11, 14, 18 and 21 criteria. Each exercise counts with the variables *ranking_table*, *available_budget*, *cost_matrix_client* with the following format.

# %% [markdown]
# - *ranking_table*: Python dictionary containing the different clients as keys and an array of positions of each client in each criteria as values.

# %% [markdown]
# - *available_budget*: Python Int representing the maximum budget available to be spent for improvements.

# %% [markdown]
# - *cost_matrix_client*: Python dictionary containing the targeted client as key and a second dictionary as value. This second dictionary is composed of tuples representing (criteria, position t - 1) as keys and the improvement costs as values. The "forbidden movements", like worsening one position, have been disabled by configuring a budget greater than the available one e.g. *available_budget + 1*.

# %% [markdown]
# ##7 criteria

# %%
ranking_table = {1: [2, 5, 4, 3, 3, 3, 4],
                 2: [1, 4, 3, 1, 4, 2, 2],
                 3: [3, 3, 2, 2, 1, 1, 1],
                 4: [4, 1, 5, 4, 5, 5, 5],
                 5: [5, 2, 1, 5, 2, 4, 3]}

available_budget = 43

cost_matrix_client =  {4: {(1,5):available_budget+1,(1,4):5,(1,3):9,(1,2):3,
                           (2,5):available_budget+1,(2,4):available_budget+1,(2,3):available_budget+1,(2,2):available_budget+1,
                           (3,5):6,(3,4):8,(3,3):2,(3,2):5,
                           (4,5):available_budget+1,(4,4):1,(4,3):7,(4,2):6,
                           (5,5):1,(5,4):4,(5,3):9,(5,2):5,
                           (6,5):8,(6,4):4,(6,3):7,(6,2):8,
                           (7,5):3,(7,4):7,(7,3):5,(7,2):2}}

# %% [markdown]
# ##11 criteria

# %%
ranking_table = {1: [2, 4, 2, 4, 3, 5, 2, 1, 4, 2, 2],
                 2: [4, 3, 4, 3, 5, 1, 3, 4, 2, 3, 3],
                 3: [1, 2, 3, 5, 4, 2, 1, 5, 1, 1, 4],
                 4: [3, 5, 5, 1, 2, 4, 5, 3, 5, 5, 5],
                 5: [5, 1, 1, 2, 1, 3, 4, 2, 3, 4, 1]}

available_budget = 33

cost_matrix_client =  {4: {(1,5):available_budget+1,(1,4):available_budget+1,(1,3):5,(1,2):7,
                           (2,5):9,(2,4):3,(2,3):1,(2,2):4,
                           (3,5):7,(3,4):2,(3,3):5,(3,2):1,
                           (4,5):available_budget+1,(4,4):available_budget+1,(4,3):available_budget+1,(4,2):available_budget+1,
                           (5,5):available_budget+1,(5,4):available_budget+1,(5,3):available_budget+1,(5,2):2,
                           (6,5):available_budget+1,(6,4):3,(6,3):5,(6,2):6,
                           (7,5):8,(7,4):5,(7,3):4,(7,2):2,
                           (8,5):available_budget+1,(8,4):available_budget+1,(8,3):7,(8,2):1,
                           (9,5):5,(9,4):4,(9,3):3,(9,2):6,
                           (10,5):1,(10,4):4,(10,3):6,(10,2):5,
                           (11,5):5,(11,4):2,(11,3):9,(11,2):3}}

# %% [markdown]
# ##14 criteria

# %%
ranking_table = {1: [4, 3, 2, 3, 3, 5, 3, 5, 3, 5, 3, 1, 5, 5],
                 2: [2, 4, 1, 5, 2, 4, 2, 2, 5, 3, 4, 3, 1, 4],
                 3: [5, 5, 4, 1, 1, 2, 1, 4, 2, 1, 1, 2, 4, 2],
                 4: [3, 1, 3, 2, 4, 1, 4, 3, 4, 4, 5, 4, 3, 1],
                 5: [1, 2, 5, 4, 5, 3, 5, 1, 1, 2, 2, 5, 2, 3]}

available_budget = 15

cost_matrix_client =  {4: {(1,5):available_budget+1,(1,4):available_budget+1,(1,3):5,(1,2):2,
                           (2,5):available_budget+1,(2,4):available_budget+1,(2,3):available_budget+1,(2,2):available_budget+1,
                           (3,5):available_budget+1,(3,4):available_budget+1,(3,3):6,(3,2):1,
                           (4,5):available_budget+1,(4,4):available_budget+1,(4,3):available_budget+1,(4,2):7,
                           (5,5):available_budget+1,(5,4):5,(5,3):9,(5,2):2,
                           (6,5):available_budget+1,(6,4):available_budget+1,(6,3):available_budget+1,(6,2):available_budget+1,
                           (7,5):available_budget+1,(7,4):6,(7,3):3,(7,2):8,
                           (8,5):available_budget+1,(8,4):available_budget+1,(8,3):4,(8,2):6,
                           (9,5):available_budget+1,(9,4):7,(9,3):1,(9,2):5,
                           (10,5):available_budget+1,(10,4):6,(10,3):3,(10,2):2,
                           (11,5):3,(11,4):8,(11,3):1,(11,2):4,
                           (12,5):available_budget+1,(12,4):5,(12,3):8,(12,2):3,
                           (13,5):available_budget+1,(13,4):available_budget+1,(13,3):5,(13,2):1,
                           (14,5):available_budget+1,(14,4):available_budget+1,(14,3):available_budget+1,(14,2):available_budget+1}}

# %% [markdown]
# ##18 criteria

# %%
ranking_table = {1: [3, 1, 5, 4, 5, 3, 4, 2, 1, 5, 1, 3, 4, 1, 3, 2, 5, 3],
                 2: [4, 3, 3, 5, 4, 2, 3, 3, 2, 3, 4, 5, 3, 3, 2, 3, 1, 5],
                 3: [1, 2, 4, 1, 1, 4, 1, 4, 4, 2, 3, 4, 2, 5, 5, 4, 2, 1],
                 4: [5, 5, 2, 2, 2, 5, 2, 5, 5, 4, 5, 2, 5, 2, 4, 5, 4, 4],
                 5: [2, 4, 1, 3, 3, 1, 5, 1, 3, 1, 2, 1, 1, 4, 1, 1, 3, 2]}

available_budget = 25

cost_matrix_client =   {4: {(1,5):5,(1,4):7,(1,3):3,(1,2):8,
                            (2,5):1,(2,4):7,(2,3):5,(2,2):2,
                            (3,5):available_budget+1,(3,4):available_budget+1,(3,3):available_budget+1,(3,2):7,
                            (4,5):available_budget+1,(4,4):available_budget+1,(4,3):available_budget+1,(4,2):3,
                            (5,5):available_budget+1,(5,4):available_budget+1,(5,3):available_budget+1,(5,2):6,
                            (6,5):3,(6,4):7,(6,3):2,(6,2):4,
                            (7,5):available_budget+1,(7,4):available_budget+1,(7,3):available_budget+1,(7,2):8,
                            (8,5):3,(8,4):7,(8,3):2,(8,2):4,
                            (9,5):8,(9,4):4,(9,3):1,(9,2):2,
                            (10,5):available_budget+1,(10,4):6,(10,3):1,(10,2):3,
                            (11,5):5,(11,4):2,(11,3):6,(11,2):4,
                            (12,5):available_budget+1,(12,4):available_budget+1,(12,3):available_budget+1,(12,2):9,
                            (13,5):1,(13,4):6,(13,3):5,(13,2):8,
                            (14,5):available_budget+1,(14,4):available_budget+1,(14,3):available_budget+1,(14,2):4,
                            (15,5):available_budget+1,(15,4):7,(15,3):6,(15,2):3,
                            (16,5):6,(16,4):3,(16,3):8,(16,2):1,
                            (17,5):available_budget+1,(17,4):6,(17,3):3,(17,2):8,
                            (18,5):available_budget+1,(18,4):3,(18,3):1,(18,2):5}}

# %% [markdown]
# ##21 criteria

# %%
ranking_table = {1: [5, 5, 2, 1, 2, 3, 4, 4, 2, 2, 1, 2, 1, 2, 4, 1, 2, 1, 2, 5, 4],
                 2: [1, 1, 4, 3, 3, 5, 3, 2, 1, 1, 5, 3, 2, 4, 2, 3, 5, 4, 5, 2, 1],
                 3: [2, 4, 5, 5, 1, 1, 5, 5, 5, 4, 4, 1, 3, 1, 5, 4, 1, 3, 1, 4, 2],
                 4: [3, 2, 1, 4, 4, 4, 2, 3, 3, 3, 3, 4, 5, 3, 1, 2, 3, 5, 4, 1, 3],
                 5: [4, 3, 3, 2, 5, 2, 1, 1, 4, 5, 2, 5, 4, 5, 3, 5, 4, 2, 3, 3, 5]}


available_budget = 20

cost_matrix_client =  {4: {(1,5):available_budget+1,(1,4):available_budget+1,(1,3):2,(1,2):4,
                           (2,5):available_budget+1,(2,4):available_budget+1,(2,3):available_budget+1,(2,2):6,
                           (3,5):available_budget+1,(3,4):available_budget+1,(3,3):available_budget+1,(3,2):available_budget+1,
                           (4,5):available_budget+1,(4,4):7,(4,3):3,(4,2):6,
                           (5,5):available_budget+1,(5,4):6,(5,3):8,(5,2):1,
                           (6,5):available_budget+1,(6,4):3,(6,3):6,(6,2):8,
                           (7,5):available_budget+1,(7,4):available_budget+1,(7,3):available_budget+1,(7,2):5,
                           (8,5):available_budget+1,(8,4):available_budget+1,(8,3):7,(8,2):1,
                           (9,5):available_budget+1,(9,4):available_budget+1,(9,3):4,(9,2):8,
                           (10,5):available_budget+1,(10,4):available_budget+1,(10,3):3,(10,2):1,
                           (11,5):available_budget+1,(11,4):available_budget+1,(11,3):7,(11,2):5,
                           (12,5):available_budget+1,(12,4):1,(12,3):7,(12,2):9,
                           (13,5):3,(13,4):8,(13,3):2,(13,2):4,
                           (14,5):available_budget+1,(14,4):available_budget+1,(14,3):7,(14,2):4,
                           (15,5):available_budget+1,(15,4):available_budget+1,(15,3):available_budget+1,(15,2):available_budget+1,
                           (16,5):available_budget+1,(16,4):available_budget+1,(16,3):available_budget+1,(16,2):6,
                           (17,5):available_budget+1,(17,4):available_budget+1,(17,3):3,(17,2):6,
                           (18,5):7,(18,4):4,(18,3):2,(18,2):6,
                           (19,5):available_budget+1,(19,4):8,(19,3):2,(19,2):5,
                           (20,5):available_budget+1,(20,4):available_budget+1,(20,3):available_budget+1,(20,2):available_budget+1,
                           (21,5):available_budget+1,(21,4):available_budget+1,(21,3):4,(21,2):8}}
