# %% [markdown]
# #Cases with 4 variables

# %% [markdown]
# This file contains the cases used in the simulations with 4 variables for 7, 11, 14, 18 and 21 criteria. Each exercise counts with the variables *ranking_table*, *available_budget*, *cost_matrix_client* with the following format.

# %% [markdown]
# - *ranking_table*: Python dictionary containing the different clients as keys and an array of positions of each client in each criteria as values.

# %% [markdown]
# - *available_budget*: Python Int representing the maximum budget available to be spent for improvements.

# %% [markdown]
# - *cost_matrix_client*: Python dictionary containing the targeted client as key and a second dictionary as value. This second dictionary is composed of tuples representing (criteria, position t - 1) as keys and the improvement costs as values. The "forbidden movements", like worsening one position, have been disabled by configuring a budget greater than the available one e.g. *available_budget + 1*.

# %% [markdown]
# ##7 criteria

# %%
ranking_table = {1: [4, 3, 2, 4, 2, 1, 1],
                 2: [2, 1, 3, 1, 3, 4, 3],
                 3: [3, 4, 4, 2, 4, 3, 4],
                 4: [1, 2, 1, 3, 1, 2, 2]}

available_budget = 15

cost_matrix_client =  {1: {(1, 4): 6, (1, 3): 6, (1, 2): 6,
                           (2, 4): available_budget+1, (2, 3): 2, (2, 2): 4,
                           (3, 4): available_budget+1, (3, 3): available_budget+1, (3, 2): 2,
                           (4, 4): 1, (4, 3): 4, (4, 2): 8,
                           (5, 4): available_budget+1, (5, 3): available_budget+1, (5, 2): 5,
                           (6, 4): available_budget+1, (6, 3): available_budget+1, (6, 2): available_budget+1,
                           (7, 4): available_budget+1, (7, 3): available_budget+1, (7, 2): available_budget+1}}

# %% [markdown]
# ##11 criteria

# %%
ranking_table = {1: [3, 3, 3, 4, 3, 3, 1, 4, 2, 3, 3],
                 2: [1, 2, 2, 2, 1, 4, 3, 1, 1, 4, 4],
                 3: [4, 4, 4, 1, 4, 2, 4, 2, 3, 2, 1],
                 4: [2, 1, 1, 3, 2, 1, 2, 3, 4, 1, 2]}

available_budget = 19

cost_matrix_client =  {1: {(1, 4): available_budget+1, (1, 3): 1, (1, 2): 4,
                           (2, 4): available_budget+1, (2, 3): 3, (2, 2): 4,
                           (3, 4): available_budget+1, (3, 3): 1, (3, 2): 4,
                           (4, 4): 6, (4, 3): 7, (4, 2): 9,
                           (5, 4): available_budget+1, (5, 3): 9, (5, 2): 9,
                           (6, 4): available_budget+1, (6, 3): 4, (6, 2): 4,
                           (7, 4): available_budget+1, (7, 3): available_budget+1, (7, 2): available_budget+1,
                           (8, 4): 3, (8, 3): 3, (8, 2): 2,
                           (9, 4): available_budget+1, (9, 3): available_budget+1, (9, 2): 2,
                           (10, 4): available_budget+1, (10, 3): 2, (10, 2): 1,
                           (11, 4): available_budget+1, (11, 3): 6, (11, 2): 9}}

# %% [markdown]
# ##14 criteria

# %%
ranking_table = {1: [3, 3, 4, 4, 3, 2, 2, 3, 1, 4, 4, 1, 1, 1],
                 2: [4, 2, 1, 1, 2, 1, 1, 1, 4, 3, 2, 4, 4, 2],
                 3: [1, 1, 3, 2, 4, 3, 3, 4, 2, 2, 3, 2, 3, 3],
                 4: [2, 4, 2, 3, 1, 4, 4, 2, 3, 1, 1, 3, 2, 4]}

available_budget = 12

cost_matrix_client =  {1: {(1, 4): available_budget+1, (1, 3): 3, (1, 2): 4,
                           (2, 4): available_budget+1, (2, 3): 4,
                           (2, 2): 7, (3, 4): 7, (3, 3): 2,
                           (3, 2): 4, (4, 4): 6, (4, 3): 7,
                           (4, 2): 6, (5, 4): available_budget+1, (5, 3): 1, (5, 2): 2,
                           (6, 4): available_budget+1, (6, 3): available_budget+1, (6, 2): 7,
                           (7, 4): available_budget+1, (7, 3): available_budget+1, (7, 2): 7,
                           (8, 4): available_budget+1, (8, 3): 4, (8, 2): 7,
                           (9, 4): available_budget+1, (9, 3): available_budget+1, (9, 2): available_budget+1,
                           (10, 4): 1, (10, 3): 1, (10, 2): 3,
                           (11, 4): 2, (11, 3): 6, (11, 2): 3,
                           (12, 4): available_budget+1, (12, 3): available_budget+1, (12, 2): available_budget+1,
                           (13, 4): available_budget+1, (13, 3): available_budget+1, (13, 2): available_budget+1,
                           (14, 4): available_budget+1, (14, 3): available_budget+1, (14, 2): available_budget+1}}

# %% [markdown]
# ##18 criteria

# %%
ranking_table =  {1: [3, 3, 4, 3, 1, 4, 3, 1, 4, 4, 1, 2, 3, 4, 1, 2, 4, 3],
                  2: [2, 4, 3, 2, 2, 1, 1, 2, 1, 1, 4, 3, 2, 2, 4, 3, 2, 1],
                  3: [4, 1, 1, 1, 3, 2, 2, 3, 3, 2, 2, 4, 1, 1, 3, 4, 1, 4],
                  4: [1, 2, 2, 4, 4, 3, 4, 4, 2, 3, 3, 1, 4, 3, 2, 1, 3, 2]}

available_budget = 9

cost_matrix_client =  {1: {(1, 4): available_budget+1, (1, 3): 6, (1, 2): 3,
                           (2, 4): available_budget+1, (2, 3): 7, (2, 2): 8,
                           (3, 4): 9, (3, 3): 4, (3, 2): 2,
                           (4, 4): available_budget+1, (4, 3): 1, (4, 2): 5,
                           (5, 4): available_budget+1, (5, 3): available_budget+1, (5, 2): available_budget+1,
                           (6, 4): 8, (6, 3): 9, (6, 2): 9,
                           (7, 4): available_budget+1, (7, 3): 8, (7, 2): 2,
                           (8, 4): available_budget+1, (8, 3): available_budget+1, (8, 2): available_budget+1,
                           (9, 4): 5, (9, 3): 1, (9, 2): 7,
                           (10, 4): 9, (10, 3): 6, (10, 2): 7,
                           (11, 4): available_budget+1, (11, 3): available_budget+1, (11, 2): available_budget+1,
                           (12, 4): available_budget+1, (12, 3): available_budget+1, (12, 2): 1,
                           (13, 4): available_budget+1, (13, 3): 2, (13, 2): 8,
                           (14, 4): 2, (14, 3): 7, (14, 2): 1,
                           (15, 4): available_budget+1, (15, 3): available_budget+1, (15, 2): available_budget+1,
                           (16, 4): available_budget+1, (16, 3): available_budget+1, (16, 2): 7,
                           (17, 4): 5, (17, 3): 7, (17, 2): 4,
                           (18, 4): available_budget+1, (18, 3): 4, (18, 2): 4}}

# %% [markdown]
# ##21 criteria

# %%
ranking_table = {1: [3, 3, 1, 3, 1, 3, 1, 4, 3, 4, 3, 3, 4, 3, 4, 2, 4, 4, 2, 4, 1],
                 2: [4, 1, 4, 2, 4, 1, 2, 1, 2, 1, 4, 2, 3, 1, 2, 4, 1, 3, 1, 1, 3],
                 3: [1, 2, 3, 1, 3, 4, 4, 3, 4, 2, 2, 1, 2, 2, 3, 1, 3, 2, 3, 3, 2],
                 4: [2, 4, 2, 4, 2, 2, 3, 2, 1, 3, 1, 4, 1, 4, 1, 3, 2, 1, 4, 2, 4]}

available_budget = 31

cost_matrix_client =  {1: {(1, 4): available_budget+1, (1, 3): 3, (1, 2): 6,
                           (2, 4): available_budget+1, (2, 3): 9, (2, 2): 9,
                           (3, 4): available_budget+1, (3, 3): available_budget+1, (3, 2): available_budget+1,
                           (4, 4): available_budget+1, (4, 3): 9, (4, 2): 6,
                           (5, 4): available_budget+1, (5, 3): available_budget+1, (5, 2): available_budget+1,
                           (6, 4): available_budget+1, (6, 3): 7, (6, 2): 9,
                           (7, 4): available_budget+1, (7, 3): available_budget+1, (7, 2): available_budget+1,
                           (8, 4): 9, (8, 3): 9, (8, 2): 8,
                           (9, 4): available_budget+1, (9, 3): 8, (9, 2): 2,
                           (10, 4): 9, (10, 3): 7, (10, 2): 1,
                           (11, 4): available_budget+1, (11, 3): 3, (11, 2): 3,
                           (12, 4): available_budget+1, (12, 3): 4, (12, 2): 4,
                           (13, 4): 9, (13, 3): 5, (13, 2): 4,
                           (14, 4): available_budget+1, (14, 3): 4, (14, 2): 4,
                           (15, 4): 1, (15, 3): 6, (15, 2): 2,
                           (16, 4): available_budget+1, (16, 3): available_budget+1, (16, 2): 8,
                           (17, 4): 4, (17, 3): 9, (17, 2): 2,
                           (18, 4): 4, (18, 3): 9, (18, 2): 2,
                           (19, 4): available_budget+1, (19, 3): available_budget+1, (19, 2): 1,
                           (20, 4): 4, (20, 3): 2, (20, 2): 1,
                           (21, 4): available_budget+1, (21, 3): available_budget+1, (21, 2): available_budget+1}}
