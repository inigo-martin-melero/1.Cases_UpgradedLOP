# %% [markdown]
# #Cases with 7 variables

# %% [markdown]
# This file contains the cases used in the simulations with 7 variables for 7, 11, 14, 18 and 21 criteria. Each exercise counts with the variables *ranking_table*, *available_budget*, *cost_matrix_client* with the following format.

# %% [markdown]
# - *ranking_table*: Python dictionary containing the different clients as keys and an array of positions of each client in each criteria as values.

# %% [markdown]
# - *available_budget*: Python Int representing the maximum budget available to be spent for improvements.

# %% [markdown]
# - *cost_matrix_client*: Python dictionary containing the targeted client as key and a second dictionary as value. This second dictionary is composed of tuples representing (criteria, position t - 1) as keys and the improvement costs as values. The "forbidden movements", like worsening one position, have been disabled by configuring a budget greater than the available one e.g. *available_budget + 1*.

# %% [markdown]
# ##7 criteria

# %%
ranking_table = {1: [2, 7, 2, 7, 7, 3, 5],
                 2: [4, 3, 3, 6, 6, 4, 6],
                 3: [6, 2, 5, 5, 4, 1, 1],
                 4: [7, 6, 6, 3, 5, 7, 3],
                 5: [1, 1, 1, 2, 2, 6, 4],
                 6: [3, 4, 4, 4, 3, 2, 7],
                 7: [5, 5, 7, 1, 1, 5, 2]}

available_budget = 33

cost_matrix_client =  {4: {(1,7):5,(1,6):3,(1,5):4,(1,4):1,(1,3):6,(1,2):3,
                           (2,7):available_budget+1,(2,6):9,(2,5):3,(2,4):6,(2,3):8,(2,2):1,
                           (3,7):available_budget+1,(3,6):1,(3,5):5,(3,4):2,(3,3):7,(3,2):4,
                           (4,7):available_budget+1,(4,6):available_budget+1,(4,5):available_budget+1,(4,4):available_budget+1,(4,3):3,(4,2):5,
                           (5,7):available_budget+1,(5,6):available_budget+1,(5,5):2,(5,4):7,(5,3):1,(5,2):4,
                           (6,7):7,(6,6):2,(6,5):5,(6,4):8,(6,3):3,(6,2):1,
                           (7,7):available_budget+1,(7,6):available_budget+1,(7,5):available_budget+1,(7,4):available_budget+1,(7,3):5,(7,2):2}}

# %% [markdown]
# ##11 criteria

# %%
ranking_table = {1: [2, 1, 3, 4, 7, 2, 3, 2, 4, 6, 6],
                 2: [1, 5, 6, 2, 1, 4, 5, 5, 1, 4, 3],
                 3: [3, 7, 1, 1, 6, 1, 7, 6, 3, 3, 2],
                 4: [7, 6, 5, 5, 5, 5, 6, 1, 7, 5, 4],
                 5: [5, 3, 2, 7, 3, 7, 1, 3, 6, 1, 1],
                 6: [4, 4, 7, 6, 2, 6, 4, 7, 5, 7, 5],
                 7: [6, 2, 4, 3, 4, 3, 2, 4, 2, 2, 7]}

available_budget = 55

cost_matrix_client =  {4: {(1,7):4,(1,6):5,(1,5):2,(1,4):7,(1,3):1,(1,2):3,
                           (2,7):available_budget+1,(2,6):4,(2,5):5,(2,4):3,(2,3):8,(2,2):2,
                           (3,7):available_budget+1,(3,6):available_budget+1,(3,5):1,(3,4):5,(3,3):2,(3,2):6,
                           (4,7):available_budget+1,(4,6):available_budget+1,(4,5):7,(4,4):3,(4,3):8,(4,2):1,
                           (5,7):available_budget+1,(5,6):available_budget+1,(5,5):3,(5,4):6,(5,3):2,(5,2):4,
                           (6,7):available_budget+1,(6,6):available_budget+1,(6,5):1,(6,4):4,(6,3):6,(6,2):8,
                           (7,7):available_budget+1,(7,6):7,(7,5):4,(7,4):1,(7,3):2,(7,2):5,
                           (8,7):available_budget+1,(8,6):available_budget+1,(8,5):available_budget+1,(8,4):available_budget+1,(8,3):available_budget+1,(8,2):available_budget+1,
                           (9,7):4,(9,6):6,(9,5):1,(9,4):2,(9,3):7,(9,2):6,
                           (10,7):available_budget+1,(10,6):available_budget+1,(10,5):4,(10,4):6,(10,3):3,(10,2):2,
                           (11,7):available_budget+1,(11,6):available_budget+1,(11,5):available_budget+1,(11,4):3,(11,3):9,(11,2):2}}

# %% [markdown]
# ##14 criteria

# %%
ranking_table = {1: [6, 1, 4, 2, 1, 5, 1, 2, 2, 6, 5, 5, 7, 5],
                 2: [3, 4, 1, 6, 2, 4, 6, 3, 3, 1, 1, 3, 2, 3],
                 3: [1, 5, 6, 4, 5, 3, 3, 5, 1, 4, 6, 4, 3, 7],
                 4: [5, 2, 5, 7, 3, 7, 5, 7, 7, 7, 4, 2, 4, 1],
                 5: [7, 6, 7, 3, 4, 6, 2, 6, 6, 2, 2, 1, 6, 4],
                 6: [2, 7, 2, 1, 6, 1, 4, 1, 5, 5, 7, 7, 5, 6],
                 7: [4, 3, 3, 5, 7, 2, 7, 4, 4, 3, 3, 6, 1, 2]}

available_budget = 15

cost_matrix_client =  {4: {(1,7):available_budget+1,(1,6):available_budget+1,(1,5):4,(1,4):6,(1,3):3,(1,2):2,
                           (2,7):available_budget+1,(2,6):available_budget+1,(2,5):available_budget+1,(2,4):available_budget+1,(2,3):available_budget+1,(2,2):2,
                           (3,7):available_budget+1,(3,6):available_budget+1,(3,5):4,(3,4):5,(3,3):2,(3,2):6,
                           (4,7):2,(4,6):4,(4,5):7,(4,4):3,(4,3):8,(4,2):1,
                           (5,7):available_budget+1,(5,6):available_budget+1,(5,5):available_budget+1,(5,4):available_budget+1,(5,3):5,(5,2):31,
                           (6,7):6,(6,6):3,(6,5):8,(6,4):1,(6,3):4,(6,2):8,
                           (7,7):available_budget+1,(7,6):available_budget+1,(7,5):3,(7,4):4,(7,3):2,(7,2):7,
                           (8,7):1,(8,6):6,(8,5):4,(8,4):2,(8,3):9,(8,2):3,
                           (9,7):6,(9,6):2,(9,5):4,(9,4):1,(9,3):3,(9,2):6,
                           (10,7):1,(10,6):8,(10,5):4,(10,4):6,(10,3):3,(10,2):2,
                           (11,7):available_budget+1,(11,6):available_budget+1,(11,5):available_budget+1,(11,4):3,(11,3):9,(11,2):2,
                           (12,7):available_budget+1,(12,6):available_budget+1,(12,5):available_budget+1,(12,4):available_budget+1,(12,3):available_budget+1,(12,2):6,
                           (13,7):available_budget+1,(13,6):available_budget+1,(13,5):available_budget+1,(13,4):3,(13,3):5,(13,2):1,
                           (14,7):available_budget+1,(14,6):available_budget+1,(14,5):available_budget+1,(14,4):available_budget+1,(14,3):available_budget+1,(14,2):available_budget+1}}

# %% [markdown]
# ##18 criteria

# %%
ranking_table = {1: [2, 6, 4, 1, 3, 4, 7, 1, 3, 2, 4, 7, 1, 1, 4, 2, 7, 4],
                 2: [1, 4, 3, 2, 1, 3, 6, 7, 5, 6, 5, 5, 7, 3, 6, 1, 2, 2],
                 3: [3, 2, 6, 7, 2, 2, 1, 2, 7, 3, 3, 2, 5, 5, 2, 7, 3, 1],
                 4: [6, 3, 7, 6, 7, 5, 5, 3, 2, 7, 7, 4, 3, 7, 7, 3, 5, 5],
                 5: [5, 5, 1, 5, 5, 6, 4, 4, 1, 5, 2, 6, 2, 2, 5, 4, 6, 6],
                 6: [7, 7, 2, 4, 4, 7, 3, 5, 6, 4, 1, 3, 6, 6, 1, 5, 1, 7],
                 7: [4, 1, 5, 3, 6, 1, 2, 6, 4, 1, 6, 1, 4, 4, 3, 6, 4, 3]}

available_budget = 47

cost_matrix_client =  {4: {(1,7):available_budget+1,(1,6):3,(1,5):8,(1,4):5,(1,3):1,(1,2):9,
                           (2,7):available_budget+1,(2,6):available_budget+1,(2,5):available_budget+1,(2,4):available_budget+1,(2,3):7,(2,2):4,
                           (3,7):4,(3,6):7,(3,5):5,(3,4):2,(3,3):3,(3,2):1,
                           (4,7):available_budget+1,(4,6):5,(4,5):4,(4,4):2,(4,3):1,(4,2):6,
                           (5,7):2,(5,6):4,(5,5):1,(5,4):8,(5,3):4,(5,2):6,
                           (6,7):available_budget+1,(6,6):available_budget+1,(6,5):3,(6,4):2,(6,3):6,(6,2):2,
                           (7,7):available_budget+1,(7,6):available_budget+1,(7,5):5,(7,4):8,(7,3):3,(7,2):4,
                           (8,7):available_budget+1,(8,6):available_budget+1,(8,5):available_budget+1,(8,4):available_budget+1,(8,3):3,(8,2):6,
                           (9,7):available_budget+1,(9,6):available_budget+1,(9,5):available_budget+1,(9,4):available_budget+1,(9,3):available_budget+1,(9,2):9,
                           (10,7):5,(10,6):2,(10,5):1,(10,4):7,(10,3):3,(10,2):4,
                           (11,7):6,(11,6):7,(11,5):4,(11,4):6,(11,3):8,(11,2):2,
                           (12,7):available_budget+1,(12,6):available_budget+1,(12,5):available_budget+1,(12,4):3,(12,3):1,(12,2):6,
                           (13,7):available_budget+1,(13,6):available_budget+1,(13,5):available_budget+1,(13,4):available_budget+1,(13,3):5,(13,2):8,
                           (14,7):2,(14,6):5,(14,5):3,(14,4):6,(14,3):8,(14,2):1,
                           (15,7):5,(15,6):2,(15,5):7,(15,4):2,(15,3):5,(15,2):9,
                           (16,7):available_budget+1,(16,6):available_budget+1,(16,5):available_budget+1,(16,4):available_budget+1,(16,3):5,(16,2):1,
                           (17,7):available_budget+1,(17,6):available_budget+1,(17,5):3,(17,4):4,(17,3):7,(17,2):1,
                           (18,7):available_budget+1,(18,6):available_budget+1,(18,5):2,(18,4):4,(18,3):3,(18,2):2}}

# %% [markdown]
# ##21 criteria

# %%
ranking_table = {1: [5, 5, 3, 1, 3, 2, 2, 7, 1, 7, 4, 7, 3, 4, 1, 7, 5, 6, 6, 2, 7],
                 2: [4, 4, 4, 7, 7, 3, 1, 6, 7, 4, 1, 1, 4, 7, 4, 4, 3, 2, 7, 6, 4],
                 3: [1, 7, 7, 5, 2, 1, 4, 2, 5, 6, 2, 2, 1, 3, 3, 6, 6, 5, 1, 5, 3],
                 4: [6, 3, 1, 2, 4, 7, 5, 5, 3, 1, 6, 3, 6, 5, 5, 5, 7, 7, 2, 4, 1],
                 5: [3, 2, 5, 3, 1, 5, 7, 4, 2, 2, 3, 5, 2, 6, 7, 3, 1, 1, 4, 1, 2],
                 6: [2, 1, 6, 6, 6, 6, 3, 3, 4, 3, 7, 4, 5, 2, 2, 1, 2, 4, 5, 7, 5],
                 7: [7, 6, 2, 4, 5, 4, 6, 1, 6, 5, 5, 6, 7, 1, 6, 2, 4, 3, 3, 3, 6]}


available_budget = 20

cost_matrix_client =  {4: {(1,7):available_budget+1,(1,6):3,(1,5):8,(1,4):5,(1,3):1,(1,2):9,
                           (2,7):available_budget+1,(2,6):available_budget+1,(2,5):available_budget+1,(2,4):available_budget+1,(2,3):7,(2,2):4,
                           (3,7):available_budget+1,(3,6):available_budget+1,(3,5):available_budget+1,(3,4):available_budget+1,(3,3):available_budget+1,(3,2):available_budget+1,
                           (4,7):available_budget+1,(4,6):available_budget+1,(4,5):available_budget+1,(4,4):available_budget+1,(4,3):available_budget+1,(4,2):6,
                           (5,7):available_budget+1,(5,6):available_budget+1,(5,5):available_budget+1,(5,4):8,(5,3):4,(5,2):6,
                           (6,7):9,(6,6):7,(6,5):3,(6,4):2,(6,3):6,(6,2):2,
                           (7,7):available_budget+1,(7,6):available_budget+1,(7,5):5,(7,4):8,(7,3):3,(7,2):4,
                           (8,7):available_budget+1,(8,6):available_budget+1,(8,5):4,(8,4):7,(8,3):3,(8,2):6,
                           (9,7):available_budget+1,(9,6):available_budget+1,(9,5):available_budget+1,(9,4):available_budget+1,(9,3):3,(9,2):9,
                           (10,7):available_budget+1,(10,6):available_budget+1,(10,5):available_budget+1,(10,4):available_budget+1,(10,3):available_budget+1,(10,2):available_budget+1,
                           (11,7):available_budget+1,(11,6):7,(11,5):4,(11,4):6,(11,3):8,(11,2):2,
                           (12,7):available_budget+1,(12,6):available_budget+1,(12,5):available_budget+1,(12,4):available_budget+1,(12,3):1,(12,2):6,
                           (13,7):available_budget+1,(13,6):4,(13,5):7,(13,4):1,(13,3):5,(13,2):8,
                           (14,7):available_budget+1,(14,6):available_budget+1,(14,5):3,(14,4):6,(14,3):8,(14,2):1,
                           (15,7):available_budget+1,(15,6):available_budget+1,(15,5):7,(15,4):2,(15,3):5,(15,2):9,
                           (16,7):available_budget+1,(16,6):available_budget+1,(16,5):2,(16,4):6,(16,3):5,(16,2):1,
                           (17,7):8,(17,6):6,(17,5):3,(17,4):4,(17,3):7,(17,2):1,
                           (18,7):5,(18,6):9,(18,5):2,(18,4):4,(18,3):3,(18,2):2,
                           (19,7):available_budget+1,(19,6):available_budget+1,(19,5):available_budget+1,(19,4):available_budget+1,(19,3):available_budget+1,(19,2):6,
                           (20,7):available_budget+1,(20,6):available_budget+1,(20,5):available_budget+1,(20,4):3,(20,3):6,(20,2):1,
                           (21,7):available_budget+1,(21,6):available_budget+1,(21,5):available_budget+1,(21,4):available_budget+1,(21,3):available_budget+1,(21,2):available_budget+1}}
